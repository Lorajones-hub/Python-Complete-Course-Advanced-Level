# %% [markdown]
# # Ping Pong game with sounds and music

# %%
# Ping Pong game with sounds and music

import pygame, sys

# %% [markdown]
# ## Question 1: Subclass Ball.
#
# ### Create a subclass Ball that inherits from a base class Sprite. Within this class, define the constructor special method \_\_init\_\_() and a function move(). Follow the detailed commented steps below to complete the Ball class.

# %%
# Sprite is a simple base class for visible game objects
# Use Sprite base class from sprite module from pygame module
class Ball(...): 
    
    # constructor of Ball class
    def __init__(self, image_file, speed, location = [0, 0]): 
        
        # instantiate base class
        pygame.sprite.Sprite.    # call __init__() method of base class Sprite
        
        # assign values to Ball object attributes

        self.image =    # load image of Ball object (ball), call load() method from pygame.image and pass the image_file     
        self.rect =     # get rectangle surrounding the ball image, call method get_rect() from self.image
        self.speed =    # set ball speed, use the value of speed parameter
        self.rect.left, self.rect.top =    # set ball inital location, (top, left) corner of ball rectangle
         
 
    # function to move the ball
    def move(self): 
        global points, score_text 
        
        self.rect =     # move the ball rectangle, call move() on self.rect and pass the speed
        
        # if ball rectangle hits the left or right edge of screen
        # screen is a window object created in main code
        if self.rect.left < 0 or check if right of rect is greater than the screen width: 
            # reverse ball movement on the x-axis
            # just change the sign of first element of speed list
            self.speed[0] = -self.speed[0]        
            
            # if top of ball rectangle still within the screen, means less than screen hight
            if ...:  
                hit_wall.play()     # play sound, hit_wall is a Sound object created in the main code
                
                                               
        if ... <= 0 : # if ball rectangle hits the top edge of screen
            
            # revers ball movement on the y-axis
            
            # player gets a point, increment global variable points           
            
            # update text_score with new score
            # use font.render() method and pass 3 parameters
            # font is a Font object created in the main code
            # render(text, antialias, color), text is only single line
            # antialias is boolean: if 1 (true) the characters will have smooth edges 
            score_text = font.render(...) 
            
            # play Sound get_point (player won a point)
            get_point.

# %% [markdown]
# ## Question 2: Subclass Paddle
#
# ### Create a subclass Paddle that inherits from a base class Sprite. Within this class, define the constructor special method \_\_init\_\_() to inistatiate base class and assign values to Paddle object attributes. Follow the detailed commented steps below to complete Paddle class.

# %%
# another subclass of Sprite class
class Paddle(...):
    
    # constructor of Paddle
    def __init__(self, location = [0,0]): 
        
        # inistatiate base class
        pygame.sprite.Sprite.     # call __init__() method of base class Sprite
        
        # assign values to Paddle object attributes
       
        image_surface =    # create a paddle surface, create an object of class Surface and pass is dimentions as a list
        image_surface.     # fill paddle with red, call fill method and pass the color red
        self.image    = image_surface.convert()     # change the pixel format of an image (DONE for you)
        self.rect =        # get rectangle surrounding the ball image, call method get_rect from self.image
        self.rect.left, self.rect.top =     # set paddle inital location, (top, left) corner of paddle rectangle

# %% [markdown]
# ## Question 3: Main code.
#
# ### Part 1:
# - Initialize pygame and mixer modules (DONE for you).
# - Load, set volume, and play background music (DONE for you).
# - Load other sounds and set their volumes (first sound DONE for you).

# %%
# MAIN CODE
       
pygame.init()         # initialize all imported pygame modules
pygame.mixer.init()   # initialize mixer module for Sound loading and playback


pygame.mixer.music.load("bg_music.mp3")          # Load background music
pygame.mixer.music.set_volume(0.3)               # Set volume for music
pygame.mixer.music.play(-1)                      # Play music forever

# ---------------------------------------- #
# Load other sounds and set their volumes
hit = pygame.mixer.Sound("hit_paddle.wav")          
hit.set_volume(0.4) 

# do the previous 2 steps for these sounds
"new_life.wav"                                 
"splat.wav"            
"hit_wall.wav"
"get_point.wav"
"game_over.wav"

# ---------------------------------------- #

# %% [markdown]
# ### Part 2:
# - Create a new screen or window for display.
# - Create a Clock() object to track time.
# - Create a Ball object and add it to group of sprites.
# - Create a paddle object.
# - Set the initial values of lives and points (DONE for you).
# - Create a new font object for to display points on the screen.
# - Draw the points text on the new surface (screen).
# - set text position variable (**textpos**) to [10, 10] and **done** variable to False (DONE for you).

# %%
screen = pygame.display.   # initialize a window or screen for display, call set_mode() method and pass dimensions
clock =                    # create an object to help track time, inistatiate Clock() class from pygame.time

myBall = Ball('pong.png', [15, 8], [50, 50])  # create a new Ball object (DONE for you)

ballGroup =        # add myBall to group of sprites, instantiate Group class from pygame.sprite and pass myBall
    
paddle =           # create a Paddle object

lives = 5          # initialize number of lives
points = 0         # initialize player points

# create a new Font object from a file
# Font(filename, size), keep filename= None, size is the height of the font in pixels
font =  

# draw text on a new Surface
score_text = font.render() 

textpos = [10, 10]   # position of text on main screen (top,left)
done = False         # game is not done

# %% [markdown]
# ### Part 3:
# - Code the main game loop:
#
#
# 	 - Handle MOUSEMOTION and QUIT events.
# 	 - Handle when the ball and paddle objects collide.
# 	 - Draw five balls on the main window (surface).
# 	 - Check if no more balls left (lives<=0): if yes  then handle GAME OVER! case; otherwise handle continue playing case.
#
# - Finally, call pygame.quit() to quit the game.
#
# ### Follow the detailed commented steps below to complete the main game loop. Some steps are already DONE for you.

# %%
# main game loop
running = True 
while running: 
    
    # make the program runs at most 30 frames per second
    clock.tick(30) 
    screen.          # fill screen color, call fill() method and pass the color
    
    # Handle MOUSEMOTION and QUIT events
    for event in pygame.event.get():    # get events from the queue
        
        # if the Event object’s type is equal to the constant QUIT
        # this is when the player closes the main window
        if type of event == pygame.QUIT:   
            # break the main loop to stop the game
            running = 
            
        # if the Event object’s type is equal to the constant MOUSEMOTION
        # this is when the player moves the paddle
        elif type of event == pygame.MOUSEMOTION:  
            
            # move the paddle with the mouse
            # centerx is a rect attribute, it is the center x value of the rect
            paddle.rect.centerx =   # assign the first element of event.pos
            
    # return a list containing all sprites in a Group that intersect with another sprite
    # spritecollide(sprite, group, dokill)
    # dokill is boolean, if 1 (true), all Sprites that collide will be removed from the Group
    if pygame.sprite.spritecollide(...): 
        # Play sound hit_play when the ball hits the paddle
        # reverse the ball movement on the y-axis
 
    # move the ball
    myBall.move() 
 
    # if the game still running
    if not done:
        # blit(source, dest)
        # draw source image onto dest surface
        # pass image and rect of Ball and Paddle objects
        screen.blit(...) 
        screen.blit(...) 
        
        # dest can be pair of coordinates representing the upper left corner of the source
        # draw score_text starting from textpos coordinates
        screen.blit(...) 
        
        # get the screen width
        
        # draw 5 balls on the screen adjacent to each other
        # you can change the top left corner of each ball image, I use this [width - 40 * i, 430]
        # for each of the 5 balls (lives)
        for i in range (...): 
            screen.blit(..., [width - 40 * i, 430]) 
            
        # update the contents of the entire display (DONE for you)    
        pygame.display.flip() 
 
    if myBall.rect.top >= screen.get_rect().bottom: 
        if not done: 
            # play sound splat when the player loses a life
        # decrement number of lives 
        
        
        # if no more balls to play, handle game over case
        if lives <= 0: 
            pygame.time.delay(1000)             # pause the program for 1 second(DONE for you
            # then play the ending sound bye
           
            # prepare GAME OVER message with player score
            final_text1 = "Game Over" 
            final_text2 = "Your final score is:  " + str(points) 
            
            # create Font and Surface objects for text
            # create Font objects and call font.render for final_text1 and final_text2
            ft1_font = pygame.font.Font(...)
            ft1_surf = font.render(...)
            
            ft2_font = 
            ft2_surf = 
            
            # draw both ft1_surf and ft2surf objects using blit()
            # measure the locations to blit
            # example: to blit the first suface use this top-left corner
            screen.blit(ft1_surf, [screen.get_width()/2 - ft1_surf.get_width()/2, 100]) 
            screen.blit(...) 

            # update the contents of the entire display 
  
            # set done to True, game is over
            pygame.mixer.music.fadeout(2000)        # fade out the music (DONE for you)
        
        # if the player has balls left to play, handle continue playing case
        else: 
            # pause the program for 1 second         
            # play sound new_life when a new life starts
            myBall.rect.topleft = [50, 50]          # set top left corner of the new myBall rect (DONE for you)
            screen.blit()                           # draw ball on rect
            # update the contents of the entire display
            # pause the program for 1 second


# quit pygame to uninitialize all pygame modules that have previously been initialized

# %% [markdown]
# ## Good Luck! and always HAVE FUN.
